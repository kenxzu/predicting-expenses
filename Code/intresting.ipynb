# %%
#cara2
# datapenjualan_makananpenutup = {
#     'Donat': 14,
#     'Pastel': 5,
#     'Kue Coklat': 12,
#     'Ice Cream': 19,
#     'Puding Vanila': 6,
#     'Brownies': 8,
#     'Puding Strawberi': 12,
#     'Puding Coklat': 9,
#     'Ice Cream Nutela': 10,
#     'Kue Coklat-Keju': 17,
#     'Kue Wajik': 2,
#     'Kue Sus': 9,
#     'Mochi': 13,
# }



# Mengurutkan data penjualan makanan penutup berdasarkan popularitas
# sorted_data = sorted(datapenjualan_makananpenutup.items(), key=lambda x: x[1], reverse=True)

# Membagi data menjadi nama makanan dan jumlah penjualan
# makanan = [item[0] for item in sorted_data]
# penjualan = [item[1] for item in sorted_data]

# Membuat visualisasi
# plt.figure(figsize=(10, 6))
# plt.barh(makanan, penjualan, color='skyblue')
# plt.barh(makanan[-3:], penjualan[-3:], color='red')
# plt.xlabel('Jumlah Penjualan')
# plt.ylabel('Makanan Penutup')
# plt.title('Popularitas Makanan Penutup di Kafe Biru')
# plt.gca().invert_yaxis()  # agar makanan dengan penjualan tertinggi ada di atas
# plt.show()

# %%
# # Given data
# nama_permen = ['Mentos', 'Kopiko', 'Golia', 'Yupie', 'Fisherman']
# jumlah_permen = [52, 39, 78, 13, 78]

# # Calculate the total number of candies
# total_candies = sum(jumlah_permen)

# # Calculate the probability of choosing each candy
# probabilities = [jumlah / total_candies for jumlah in jumlah_permen]

# # Create a pie chart
# plt.figure(figsize=(8, 8))
# plt.pie(probabilities, labels=nama_permen, autopct='%1.1f%%', startangle=140)
# plt.title('Percentage Chance of Choosing Each Candy')
# plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
# plt.show()

# # Probability of choosing Kopiko candy
# kopiko_index = nama_permen.index('Kopiko')
# kopiko_probability = probabilities[kopiko_index]
# print("Probability of choosing Kopiko candy:", kopiko_probability)
